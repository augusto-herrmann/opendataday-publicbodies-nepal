# %% [markdown]
# # Scraping public bodies info for Nepal

# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://mofaga.gov.np/local-contact'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content)

# %%
table = soup.find('table')

# %%
columns = [tag.text for tag in table.find_all('th')]
columns
# Out:
# ['क्रस',
#  'प्रदेश',
#  'स्थानीय तहको नाम',
#  'जिल्ला',
#  'वेवसाईट',
#  'कार्यालयको ईमेल',
#  'सम्पर्क फोन',
#  'बिस्तृतमा']

# %%
rows = table.find('tbody').find_all('tr')

# %% [markdown]
# ## Exploring the first row

# %%
first_row = rows[0]
first_row
# Out:
# <tr>
# <td>१</td>
# <td>प्रदेश नं. १</td>
# <td>फक्ताङलुङ गाउँपालिका</td>
# <td>ताप्लेजुङ</td>
# <td>
# <span class="badge badge-success">
# <a href="http://phaktanglungmun.gov.np" style="color:#fff;" target="_banner" title="http://phaktanglungmun.gov.np">
# <i class="fa fa-link"></i> Web Site</a>
# </span>
# </td>
# <td>phaktanglungmun@gmail.com</td>
# <td>021-696491</td>
# <td><button class="btn btn-primary"><i class="fa fa-eye"></i></button></td>
# </tr>

# %%
[cell.text for cell in first_row.find_all('td')]
# Out:
# ['१',
#  'प्रदेश नं. १',
#  'फक्ताङलुङ गाउँपालिका',
#  'ताप्लेजुङ',
#  '\n\n\n Web Site\n\n',
#  'phaktanglungmun@gmail.com',
#  '021-696491',
#  '']

# %%
len(columns)
# Out:
# 8

# %% [markdown]
# ## Building the data frame

# %%
df = pd.DataFrame(columns=columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [क्रस, प्रदेश, स्थानीय तहको नाम, जिल्ला, वेवसाईट, कार्यालयको ईमेल, सम्पर्क फोन, बिस्तृतमा]
# Index: []

# %%
for row in rows:
    cells = [cell.text for cell in row.find_all('td')]
    entry = dict(zip(columns, cells))
    entry['वेवसाईट'] = row.find('a').attrs['href']
    df.loc[len(df.index)] = entry.values()

# %%
df
# Out:
#    क्रस        प्रदेश            स्थानीय तहको नाम     जिल्ला  \
# 0     १  प्रदेश नं. १        फक्ताङलुङ गाउँपालिका  ताप्लेजुङ
# 1     २  प्रदेश नं. १       मिक्वाखोला गाउँपालिका  ताप्लेजुङ
# 2     ३  प्रदेश नं. १         मेरिङदेन गाउँपालिका  ताप्लेजुङ
# 3     ४  प्रदेश नं. १         मैवाखोला गाउँपालिका  ताप्लेजुङ
# 4     ५  प्रदेश नं. १   आठराई त्रिवेणी गाउँपालिका  ताप्लेजुङ
# 5     ६  प्रदेश नं. १            फुङलिङ नगरपालिका  ताप्लेजुङ
# 6     ७  प्रदेश नं. १  पाथिभरा याङ्वरक गाउँपालिका  ताप्लेजुङ
# 7     ८  प्रदेश नं. १        सिरीजङ्घा गाउँपालिका  ताप्लेजुङ
# 8     ९  प्रदेश नं. १         सिदिङ्वा गाउँपालिका  ताप्लेजुङ
# 9    १०  प्रदेश नं. १          भोटखोला गाउँपालिका  संखुवासभा
# 10   ११  प्रदेश नं. १            मकालु गाउँपालिका  संखुवासभा
# 11   १२  प्रदेश नं. १          सिलीचोङ गाउँपालिका  संखुवासभा
# 12   १३  प्रदेश नं. १           चिचिला गाउँपालिका  संखुवासभा
# 13   १४  प्रदेश नं. १         सभापोखरी गाउँपालिका  संखुवासभा
# 14   १५  प्रदेश नं. १          खाँदवारी नगरपालिका  संखुवासभा
#
#                                 वेवसाईट  \
# 0         http://phaktanglungmun.gov.np
# 1           http://mikwakholamun.gov.np
# 2            http://meringdenmun.gov.np
# 3           http://maiwakholamun.gov.np
# 4       http://aathraitribenimun.gov.np
# 5            http://phunglingmun.gov.np
# 6   http://yangwarakmuntaplejung.gov.np
# 7           http://sirijanghamun.gov.np
# 8             http://sidingbamun.gov.np
# 9            http://bhotkholamun.gov.np
# 10              http://makalumun.gov.np
# 11           http://silichongmun.gov.np
# 12            http://chichilamun.gov.np
# 13         http://savapokharimun.gov.np
# 14           http://khandbarimun.gov.np
#
#                           कार्यालयको ईमेल सम्पर्क फोन बिस्तृतमा
# 0               phaktanglungmun@gmail.com  021-696491
# 1               info@mikwakholamun.gov.np  9742691943
# 2                     meringden@gmail.com  9852660822
# 3                  maiwakholarm@gmail.com  9852660937
# 4            aathrai.tribenimun@gmail.com  9852660960
# 5                info@phunglingmun.gov.np  024-460114
# 6                 pathivarayang@gmail.com  9852660460
# 7   sirijangharuralmunicipality@gmail.com  9861991144
# 8                 sidingbarmtpj@gmail.com  9852660153
# 9                  bhotkholamun@gmail.com  9752006670
# 10              gaupalikamakalu@gmail.com  9752006670
# 11                silichonggp74@gmail.com  9752006775
# 12                info@chichilamun.gov.np  021-620770
# 13               savapokharimun@gmail.com  029-413090
# 14               info@khandbarimun.gov.np  029-560254

# %% [markdown]
# ### Scraping function

# %%
def scrape_table(url: str) -> pd.DataFrame:
    """Scrapes a table from html in the government directory at https://mofaga.gov.np/local-contact
    and returns a data frame.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    table = soup.find('table')
    columns = [tag.text for tag in table.find_all('th')]
    rows = table.find('tbody').find_all('tr')
    df = pd.DataFrame(columns=columns)
    for row in rows:
        cells = [cell.text for cell in row.find_all('td')]
        entry = dict(zip(columns, cells))
        entry['वेवसाईट'] = row.find('a').attrs['href']
        df.loc[len(df.index)] = entry.values()
    return df

# %% [markdown]
# ### Data extraction

# %% [markdown]
# Scrape the district government organizations.

# %%
df = scrape_table('https://mofaga.gov.np/local-contact/dcc-prov-1?_token=29tedmjpqp7lgXXFG7hP0rliFO5kijkX36jLRsFF&province_id=0&dist_id=&visible=500')
df
# Out:
#    क्रस              प्रदेश     जिल्ला              जिल्ला समन्वय समिति  \
# 0    1.        प्रदेश नं. १  ताप्लेजुङ  जिल्ला समन्वय समिति ताप्लेजुङ्ग
# 1    2.        प्रदेश नं. १     पाँचथर       जिल्ला समन्वय समिति पाँचथर
# 2    3.        प्रदेश नं. १       इलाम         जिल्ला समन्वय समिति इलाम
# 3    4.        प्रदेश नं. १       झापा         जिल्ला समन्वय समिति झापा
# 4    5.        प्रदेश नं. १  संखुवासभा    जिल्ला समन्वय समिति संखुवासभा
# ..  ...                 ...        ...                              ...
# 72  73.  सुदूरपश्चिम प्रदेश       बझाङ         जिल्ला समन्वय समिति बझाङ
# 73  74.  सुदूरपश्चिम प्रदेश   दार्चुला     जिल्ला समन्वय समिति दार्चुला
# 74  75.  सुदूरपश्चिम प्रदेश      बैतडी        जिल्ला समन्वय समिति बैतडी
# 75  76.  सुदूरपश्चिम प्रदेश  डडेल्धुरा     जिल्ला समन्वय समिति डडेलधुरा
# 76  77.  सुदूरपश्चिम प्रदेश   कञ्चनपुर     जिल्ला समन्वय समिति कञ्चनपुर
#
#                            वेवसाईट                          ईमेल         फोन  \
# 0       http://dcctaplejung.gov.np      info@dcctaplejung.gov.np  024-460143
# 1       http://dccpanchthar.gov.np      info@ddcpanchthar.gov.np  024-520120
# 2            http://dccilam.gov.np           info@ddcilam.gov.np  027-521776
# 3           http://dccjhapa.gov.np          info@ddcjhapa.gov.np  023-455034
# 4   http://dccsankhuwasabha.gov.np  info@ddcsankhuwasabha.gov.np  029-560044
# ..                             ...                           ...         ...
# 72        http://dccbajhang.gov.np        info@ddcbajhang.gov.np  092-421057
# 73       http://dccdarchula.gov.np                                 974950783
# 74        http://dccbaitadi.gov.np          ddcbaitadi@gmail.com  095-520144
# 75     http://dccdadeldhura.gov.np       ddcdadeldhura@gmail.com  096-410144
# 76     http://dcckanchanpur.gov.np     info@ddckanchanpur.gov.np  099-521328
#
#    एक्सन
# 0
# 1
# 2
# 3
# 4
# ..   ...
# 72
# 73
# 74
# 75
# 76
#
# [77 rows x 8 columns]

# %%
df.to_csv('data/nepal-district-govorgs.csv', index=False)

# %% [markdown]
# Scrape the local government organizations url.

# %%
df = scrape_table('https://mofaga.gov.np/local-contact?_token=29tedmjpqp7lgXXFG7hP0rliFO5kijkX36jLRsFF&province_id=&dist_id=&local_tpe=&visible=10000&q=')
df
# Out:
#     क्रस              प्रदेश           स्थानीय तहको नाम     जिल्ला  \
# 0      १        प्रदेश नं. १       फक्ताङलुङ गाउँपालिका  ताप्लेजुङ
# 1      २        प्रदेश नं. १      मिक्वाखोला गाउँपालिका  ताप्लेजुङ
# 2      ३        प्रदेश नं. १        मेरिङदेन गाउँपालिका  ताप्लेजुङ
# 3      ४        प्रदेश नं. १        मैवाखोला गाउँपालिका  ताप्लेजुङ
# 4      ५        प्रदेश नं. १  आठराई त्रिवेणी गाउँपालिका  ताप्लेजुङ
# ..   ...                 ...                        ...        ...
# 748  ७४९  सुदूरपश्चिम प्रदेश    दोधारा चाँदनी नगरपालिका   कञ्चनपुर
# 749  ७५०  सुदूरपश्चिम प्रदेश         लालझाडी गाउँपालिका   कञ्चनपुर
# 750  ७५१  सुदूरपश्चिम प्रदेश         पुनर्वास नगरपालिका   कञ्चनपुर
# 751  ७५२  सुदूरपश्चिम प्रदेश           बेलौरी नगरपालिका   कञ्चनपुर
# 752  ७५३  सुदूरपश्चिम प्रदेश        बेलडाँडी गाउँपालिका   कञ्चनपुर
#
#                               वेवसाईट                कार्यालयको ईमेल  \
# 0       http://phaktanglungmun.gov.np      phaktanglungmun@gmail.com
# 1         http://mikwakholamun.gov.np      info@mikwakholamun.gov.np
# 2          http://meringdenmun.gov.np            meringden@gmail.com
# 3         http://maiwakholamun.gov.np         maiwakholarm@gmail.com
# 4     http://aathraitribenimun.gov.np   aathrai.tribenimun@gmail.com
# ..                                ...                            ...
# 748  http://dodharachandanimun.gov.np            dcmun1015@gmail.com
# 749         http://laljhadimun.gov.np        info@laljhadimun.gov.np
# 750         http://punarbasmun.gov.np        info@punarbasmun.gov.np
# 751          http://belaurimun.gov.np  belaurimunicipality@gmail.com
# 752         http://beldandimun.gov.np        info@beldandimun.gov.np
#
#     सम्पर्क फोन बिस्तृतमा
# 0    021-696491
# 1    9742691943
# 2    9852660822
# 3    9852660937
# 4    9852660960
# ..          ...       ...
# 748  099-400030
# 749  9858754111
# 750  099-420055
# 751  099-580292
# 752  9858731111
#
# [753 rows x 8 columns]

# %%
df.to_csv('data/nepal-local-govorgs.csv', index=False)
